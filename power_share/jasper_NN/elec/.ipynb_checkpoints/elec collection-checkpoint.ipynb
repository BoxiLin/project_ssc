# %%
import numpy as np
np.random.seed(2020)  # for reproducibility
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import keras 
from keras.models import Sequential
from keras.layers import Input, Dense
from keras.models import Model
from sklearn.preprocessing import StandardScaler

# %%
#for year in np.arange(2004,2017)

year = 2004 # year to read
np.arange(2004,2017)



pwd = "/home/jasperzhang/Documents/elec/"  #data directory path

xtrain = pd.read_csv(pwd + "xtrain" + str(year) + ".csv")
ytrain = pd.read_csv(pwd + "ytrain" + str(year) + ".csv")

xtest = pd.read_csv(pwd + "xtest" + str(year) + ".csv")
ytest = pd.read_csv(pwd + "ytest" + str(year) + ".csv")


xval = pd.read_csv(pwd + "xval" + str(year) + ".csv")
yval = pd.read_csv(pwd + "yval" + str(year) + ".csv")

# %%
#data normalization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

#scale selected columns
def scaleColumns(df, cols_to_scale):

    for col in cols_to_scale:

        df[col] = pd.DataFrame(sc.fit_transform(pd.DataFrame(df[col])),columns=[col])

    return df


train_x = scaleColumns(xtrain,['precipitation','temperature','irradiance_surface','irradiance_toa','snowfall','snowfall','snow_depth','cloud_cover','air_density'])
val_x = scaleColumns(xval,['precipitation','temperature','irradiance_surface','irradiance_toa','snowfall','snowfall','snow_depth','cloud_cover','air_density'])
test_x = scaleColumns(xtest,['precipitation','temperature','irradiance_surface','irradiance_toa','snowfall','snowfall','snow_depth','cloud_cover','air_density'])
print(train_x.head())
# Out:
#    precipitation  temperature  irradiance_surface  irradiance_toa  snowfall  \
# 0       1.180939    -0.563198           -0.692805       -0.793055  0.568958
# 1       1.955355    -0.539392           -0.692805       -0.793055  0.361617
# 2       4.324156    -0.516031           -0.692805       -0.793055  1.040325
# 3       7.274312    -0.493291           -0.692805       -0.793055  0.982150
# 4       6.965739    -0.444791           -0.692805       -0.793055  1.311808
#
#    snow_depth  cloud_cover  air_density  h2  h3  ...  Apr  May  Jun  Jul  Aug  \
# 0    1.292131     1.433590     0.479720   0   0  ...    0    0    0    0    0
# 1    1.292367     1.421932     0.405605   1   0  ...    0    0    0    0    0
# 2    1.292479     1.388253     0.318520   0   1  ...    0    0    0    0    0
# 3    1.292579     1.317332     0.248110   0   0  ...    0    0    0    0    0
# 4    1.292716     1.237343     0.177701   0   0  ...    0    0    0    0    0
#
#    Sep  Oct  Nov  Dec  year
# 0    0    0    0    0  2007
# 1    0    0    0    0  2007
# 2    0    0    0    0  2007
# 3    0    0    0    0  2007
# 4    0    0    0    0  2007
#
# [5 rows x 49 columns]

# %%
test_x.head()
# Out:
#    precipitation  temperature  irradiance_surface  irradiance_toa  snowfall  \
# 0         0.0215        5.821                 0.0             0.0    0.0036
# 1         0.0183        5.271                 0.0             0.0    0.0041
# 2         0.0150        4.192                 0.0             0.0    0.0028
# 3         0.0101        2.888                 0.0             0.0    0.0011
# 4         0.0057        1.738                 0.0             0.0    0.0006
#
#    snow_depth  cloud_cover  air_density  h2  h3  ...  Apr  May  Jun  Jul  Aug  \
# 0     15.2982       0.4864       1.2256   0   0  ...    0    0    0    0    0
# 1     15.2753       0.4609       1.2296   1   0  ...    0    0    0    0    0
# 2     15.2722       0.3882       1.2364   0   1  ...    0    0    0    0    0
# 3     15.2492       0.2453       1.2442   0   0  ...    0    0    0    0    0
# 4     15.2463       0.1674       1.2517   0   0  ...    0    0    0    0    0
#
#    Sep  Oct  Nov  Dec  year
# 0    0    0    0    0  2005
# 1    0    0    0    0  2005
# 2    0    0    0    0  2005
# 3    0    0    0    0  2005
# 4    0    0    0    0  2005
#
# [5 rows x 49 columns]

# %%
# Out:
#        precipitation  temperature  irradiance_surface  irradiance_toa  \
# 0          -0.338532    -0.236887           -0.692198       -0.793260
# 1          -0.354835    -0.286451           -0.692198       -0.793260
# 2          -0.371647    -0.383688           -0.692198       -0.793260
# 3          -0.396611    -0.501201           -0.692198       -0.793260
# 4          -0.419028    -0.604836           -0.692198       -0.793260
# ...              ...          ...                 ...             ...
# 17515      -0.203013    -0.588074           -0.326675        0.211153
# 17516      -0.027246    -0.607810           -0.537314       -0.188561
# 17517       0.168899    -0.641514           -0.672937       -0.659595
# 17518       0.443503    -0.651697           -0.692172       -0.793168
# 17519       1.251011    -0.643677           -0.692198       -0.793260
#
#        snowfall  snow_depth  cloud_cover  air_density  h2  h3  ...  Apr  May  \
# 0     -0.192949    1.122585    -0.152072     0.060607   0   0  ...    0    0
# 1     -0.186058    1.119651    -0.234637     0.137087   1   0  ...    0    0
# 2     -0.203976    1.119253    -0.470029     0.267103   0   1  ...    0    0
# 3     -0.227407    1.116305    -0.932718     0.416239   0   0  ...    0    0
# 4     -0.234299    1.115934    -1.184947     0.559639   0   0  ...    0    0
# ...         ...         ...          ...          ...  ..  ..  ...  ...  ...
# 17515 -0.154356    1.352754     1.413429     0.722159   0   0  ...    0    0
# 17516 -0.045469    1.352767     1.439656     0.687743   0   0  ...    0    0
# 17517  0.137848    1.352792     1.443541     0.666711   0   0  ...    0    0
# 17518  0.303247    1.352869     1.443217     0.647591   0   0  ...    0    0
# 17519  0.476916    1.353062     1.450017     0.609351   0   0  ...    0    0
#
#        Jun  Jul  Aug  Sep  Oct  Nov  Dec  year
# 0        0    0    0    0    0    0    0  2005
# 1        0    0    0    0    0    0    0  2005
# 2        0    0    0    0    0    0    0  2005
# 3        0    0    0    0    0    0    0  2005
# 4        0    0    0    0    0    0    0  2005
# ...    ...  ...  ...  ...  ...  ...  ...   ...
# 17515    0    0    0    0    0    0    1  2006
# 17516    0    0    0    0    0    0    1  2006
# 17517    0    0    0    0    0    0    1  2006
# 17518    0    0    0    0    0    0    1  2006
# 17519    0    0    0    0    0    0    1  2006
#
# [17520 rows x 49 columns]

# %%
# Out:
# /home/jasperzhang/anaconda3/envs/dl/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(input_dim=49, units=1)`

# %%
n_input = xtrain.shape[1]
n_hidden_1 = n_input * 2  
n_hidden_2 = n_input * 4 
n_hidden_3 = n_input * 2 
n_classes = 1 
training_epochs = 20
batch_size = 64

# %%
model = Sequential()
model.add(Dense(n_hidden_1, activation='relu', input_dim=n_input)) 
model.add(Dense(n_hidden_2, activation='relu'))
model.add(Dense(n_hidden_3, activation='relu'))
model.add(Dense(n_classes))

# %%
#define our own performance evaluation year error
import keras.backend as K
def yearerr(y_true, y_pred):
    a = K.sum(y_true) - K.sum(y_pred)
    b = K.abs(a)
    return b

# %%
model.compile(loss='mse', optimizer='rmsprop', metrics=['mae',yearerr])
#model.compile(loss='mse', optimizer='adam',metrics = ['mae'])

train_y = ytrain

test_y = ytest

history = model.fit(train_x, train_y, batch_size=batch_size, epochs=training_epochs,  validation_data=(test_x, test_y))
# Out:
# Train on 87672 samples, validate on 17520 samples
# Epoch 1/20
# 87672/87672 [==============================] - 6s 66us/step - loss: 152949.0955 - mae: 308.2225 - yearerr: 5286.9902 - val_loss: 624956.3649 - val_mae: 655.9510 - val_yearerr: 38774.4727
# Epoch 2/20
# 87672/87672 [==============================] - 6s 63us/step - loss: 151738.7121 - mae: 306.8172 - yearerr: 5158.9927 - val_loss: 371831.1433 - val_mae: 507.4660 - val_yearerr: 28472.9746
# Epoch 3/20
# 87672/87672 [==============================] - 6s 64us/step - loss: 152088.8055 - mae: 307.8876 - yearerr: 5158.8237 - val_loss: 384335.2999 - val_mae: 512.6974 - val_yearerr: 28810.5039
# Epoch 4/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 151785.0790 - mae: 306.5851 - yearerr: 5175.3149 - val_loss: 424600.8037 - val_mae: 536.4351 - val_yearerr: 30173.8633
# Epoch 5/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 151798.1891 - mae: 306.5497 - yearerr: 5229.0566 - val_loss: 444093.3041 - val_mae: 557.1961 - val_yearerr: 31745.7734
# Epoch 6/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 151548.0000 - mae: 307.1815 - yearerr: 5151.4937 - val_loss: 352542.0980 - val_mae: 484.4923 - val_yearerr: 27045.2129
# Epoch 7/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 150865.3106 - mae: 305.9324 - yearerr: 5135.4365 - val_loss: 483424.6536 - val_mae: 561.8719 - val_yearerr: 31823.1562
# Epoch 8/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 151147.7312 - mae: 306.5208 - yearerr: 5069.1597 - val_loss: 516332.9370 - val_mae: 594.6632 - val_yearerr: 34719.3945
# Epoch 9/20
# 87672/87672 [==============================] - 6s 70us/step - loss: 150860.9852 - mae: 306.0812 - yearerr: 5247.7744 - val_loss: 420465.0241 - val_mae: 531.3629 - val_yearerr: 30358.4434
# Epoch 10/20
# 87672/87672 [==============================] - 6s 70us/step - loss: 150270.5227 - mae: 305.6595 - yearerr: 5176.5259 - val_loss: 415151.0018 - val_mae: 532.4837 - val_yearerr: 30356.1660
# Epoch 11/20
# 87672/87672 [==============================] - 6s 70us/step - loss: 149008.5488 - mae: 304.6975 - yearerr: 5028.2163 - val_loss: 422990.0994 - val_mae: 544.3395 - val_yearerr: 30865.1426
# Epoch 12/20
# 87672/87672 [==============================] - 6s 70us/step - loss: 149959.3937 - mae: 305.3530 - yearerr: 5149.2524 - val_loss: 367563.5606 - val_mae: 502.2463 - val_yearerr: 28087.9590
# Epoch 13/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 149469.7696 - mae: 304.6716 - yearerr: 5169.2305 - val_loss: 367568.2238 - val_mae: 495.5087 - val_yearerr: 27838.1719
# Epoch 14/20
# 87672/87672 [==============================] - 6s 70us/step - loss: 149745.6207 - mae: 304.8621 - yearerr: 5176.1465 - val_loss: 485181.5217 - val_mae: 578.2505 - val_yearerr: 33439.2148
# Epoch 15/20
# 87672/87672 [==============================] - 6s 70us/step - loss: 149536.1160 - mae: 304.8886 - yearerr: 4894.3032 - val_loss: 362843.6635 - val_mae: 497.7322 - val_yearerr: 27497.9922
# Epoch 16/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 148730.0820 - mae: 304.2266 - yearerr: 5034.7739 - val_loss: 356881.4512 - val_mae: 493.3618 - val_yearerr: 27083.5410
# Epoch 17/20
# 87672/87672 [==============================] - 6s 70us/step - loss: 148695.3453 - mae: 304.3715 - yearerr: 5062.6465 - val_loss: 353087.2935 - val_mae: 490.5725 - val_yearerr: 27329.7656
# Epoch 18/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 148194.8010 - mae: 303.4852 - yearerr: 4948.8828 - val_loss: 364490.8295 - val_mae: 497.7234 - val_yearerr: 27617.3184
# Epoch 19/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 148486.6533 - mae: 303.8073 - yearerr: 5124.5977 - val_loss: 535006.0184 - val_mae: 603.7001 - val_yearerr: 35246.9375
# Epoch 20/20
# 87672/87672 [==============================] - 6s 69us/step - loss: 147388.5451 - mae: 303.1086 - yearerr: 4948.3501 - val_loss: 514496.3122 - val_mae: 595.0602 - val_yearerr: 34648.1445

# %%
history.history['yearerr']
pred_test_y = model.predict(xval)

# %%
#history = model.fit(train_x, train_y, batch_size=batch_size, epochs=training_epochs)

pred_test_y = model.predict(xval)
print(pred_test_y)
# Out:
# [[4775.0737]
#  [4673.0366]
#  [4597.322 ]
#  ...
#  [5494.1655]
#  [5107.2534]
#  [4649.079 ]]

# %%
def maeyear(a,b):
    ymae = np.abs(np.sum(a) - np.sum(b))
    return ymae

def mae(a,b):
    ymae = np.mean(np.abs(a-b))
    return ymae

pred_acc = mae(yval, pred_test_y)
print('pred_acc',pred_acc)
# Out:
# pred_acc x    793.119435
# dtype: float64

# %%
#display the result
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# plot size
plt.figure(figsize=(25, 4), dpi=80)
plt.plot(range(len(yval)), yval, ls='-.',lw=2,c='r',label='real')
plt.plot(range(len(pred_test_y)), pred_test_y, ls='-',lw=2,c='b',label='pred')

# plot grid
plt.grid(alpha=0.4, linestyle=':')
plt.legend()
plt.xlabel('time/hour') 
plt.ylabel('electric usage')
plt.title(str(year) + ' electricity usage prediction')
# display
#plt.show()

# %%
plt.savefig(pwd + 'plot/' + str(year) +'prediction.png')
